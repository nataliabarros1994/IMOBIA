# %% [markdown]
# # Fase 4 — Analise Exploratoria de Dados (EDA)
#
# Objetivo: entender o dataset antes de modelar.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from imobia.collect.dataset import gerar_dataset_sintetico, salvar_dataset
from imobia.clean.imoveis import pipeline_limpeza
from imobia.viz.plots import histograma_precos, boxplot_por_bairro, matriz_correlacao

df = gerar_dataset_sintetico(5000)
salvar_dataset(df)
df.head()

# %% [markdown]
# ## Estatisticas descritivas

# %%
df.describe()

# %%
df.info()

# %% [markdown]
# ## Visualizacoes

# %%
histograma_precos(df);

# %%
boxplot_por_bairro(df);

# %%
matriz_correlacao(df);

# %% [markdown]
# ## Limpeza

# %%
df_limpo = pipeline_limpeza(df)
df_limpo.describe()
